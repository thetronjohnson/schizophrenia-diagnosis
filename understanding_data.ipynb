# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import mne

# %%
PATIENT_PATH = "dataset/schizophrenia/"
HEALTHY_PATH = "dataset/healthy/"

# %%
patient = pd.read_csv(PATIENT_PATH + "patient_0.csv", index_col=0)
healthy = pd.read_csv(HEALTHY_PATH + "healthy0.csv", index_col=0)

# %%
patient.head()
# Out:
#          0       1       2       3       4       5       6       7       8  \
# F7  108.01  208.82  388.84  446.45  446.45  349.24   86.41    7.20    7.20
# F3  176.42  237.63  309.63  417.65  439.25  356.44  108.01   46.81  147.62
# F4  -90.01  -72.01 -111.61 -162.02 -122.41  -72.01   46.81   86.41  118.81
# F8    7.20   18.00  -82.81 -151.22 -140.42  -32.40  118.81  129.61   28.80
# T3   39.60  129.61  277.23  356.44  309.63  208.82  -10.80  -43.20    7.20
#
#          9  ...    7670    7671    7672    7673    7674    7675    7676  \
# F7   86.41  ...   46.81    7.20 -111.61 -190.82 -352.84 -471.65 -532.86
# F3  266.43  ...  259.23  237.63    7.20 -151.22 -392.44 -471.65 -550.86
# F4  158.42  ...  187.22   79.21 -291.63 -493.25 -500.45 -432.05 -370.84
# F8    7.20  ...  118.81   39.60 -280.83 -410.44 -381.64 -313.23 -331.24
# T3   79.21  ...    0.00  -32.40 -180.02 -291.63 -471.65 -572.46 -583.26
#
#       7677    7678    7679
# F7 -532.86 -410.44 -331.24
# ...

# %%
healthy.head()
# Out:
#          0       1       2       3       4       5       6       7       8  \
# F7  347.78  507.87  488.54  369.86  347.78  408.50  488.54  449.90  369.86
# F3  198.73  358.82  449.90  309.14  149.05  229.09  557.55  637.59  488.54
# F4  637.59  659.67  488.54  328.46  248.41  298.09  389.18  369.86  259.45
# F8  298.09  317.42  317.42  289.81  289.81  369.86  408.50  339.50  138.01
# T3  278.77  378.14  378.14  317.42  328.46  389.18  469.22  488.54  557.55
#
#          9  ...    7670    7671    7672    7673    7674    7675    7676  \
# F7  427.82  ...  168.37  187.69  209.77  209.77  347.78  408.50  248.41
# F3  378.14  ... -212.53 -231.85 -220.81 -140.77   69.00  118.69  -22.08
# F4  248.41  ... -132.49 -212.53 -262.21 -201.49  -41.40  -11.04   57.96
# F8   88.32  ...  267.73  168.37   69.00   49.68   38.64   19.32  -11.04
# T3  618.27  ...  229.09  309.14  408.50  369.86  358.82  358.82  237.37
#
#       7677    7678    7679
# F7  149.05  129.73  187.69
# ...

# %%
EEG_channels = list(patient.index)
info = mne.create_info(ch_names = EEG_channels, sfreq = 128)
patient_raw = mne.io.RawArray(patient, info)
healthy_raw = mne.io.RawArray(healthy, info)
# Out:
# Creating RawArray with float64 data, n_channels=16, n_times=7680
#     Range : 0 ... 7679 =      0.000 ...    59.992 secs
# Ready.
# Creating RawArray with float64 data, n_channels=16, n_times=7680
#     Range : 0 ... 7679 =      0.000 ...    59.992 secs
# Ready.

# %% [markdown]
# ## Patient EEG data plot

# %%
patient_raw.plot(duration=5, n_channels=16,color="darkblue")
print()
# Out:
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %% [markdown]
# ## Healthy EEG Data Plot

# %%
healthy_raw.plot(duration=5, n_channels=16,color="green")
print()
# Out:
# <MNEBrowseFigure size 576x576 with 4 Axes>
